# %% [markdown]
# # L1: [Lab Title — This should match the lesson title]
# This notebook contains some guidelines for preparing Jupyter notebooks for short courses.
#
# [Any text explaining the goal and the contents of this lab.]
#
# **Note**: This is instructor notebook and the text here will be read or referenced when recording. Final published student notebooks will not have most of the markdowns, except for the headings and major notes.

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# Add your imports here.

# %% [markdown]
# ### Accessing Utils and other files

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>

# %% [markdown]
# <p style="background-color:#f2f2ff; padding:15px; border-width:3px; border-color:#e2e2ff; border-style:solid; border-radius:6px"> ⬇
# &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>. For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
#
# </div>

# %% [markdown]
# > **Different Run Results:** The output generated by AI chat models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ slightly from those shown in the video.

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI chat models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %% [markdown]
# ## Load API tokens for our 3rd party APIs

# %%
from helper import get_openai_api_key
openai_api_key = get_openai_api_key()
# Add your code here.

# %% [markdown]
# ## [Section 1 Title]
# [Optional short text explaining sections one]

# %% [markdown]
# ### Code Cell Width
# Code cells should be less than or equal to 72 characters wide if possible. Example:

# %%
#        1         2         3         4         5         6         7
#23456789012345678901234567890123456789012345678901234567890123456789012

# %%
input = "hello! "

# %% [markdown]
# Often, prompts get long. We like to follow the python PEP 8 guildelines on creatining multi-line prompts

# %%
aprompt = (f"Summarize the following comments into 5 comments: {input} "  #you can have comments in your strings this way
          "Do not invent new comments. "
          "Separate each comment with a triple hash ###. "
          "Do not enumerate them. ")
aprompt
# Out:
# 'Summarize the following comments into 5 comments: hello!  Do not invent new comments. Separate each comment with a triple hash ###. Do not enumerate them. '

# %% [markdown]
# ### [Subsection 1-1 Title]
# [Optional short text explaining subsection 1-1]

# %%
# code cell 1

# %%
# code cell 2

# %%
# code cell ...

# %%
# code cell N

# %% [markdown]
# ### [Subsection 1-2 Title]
# [Optional short text explaining subsection 1-2]

# %%
# code cell 1

# %%
# code cell 2

# %%
# code cell ...

# %%
# code cell N

# %% [markdown]
# ## Info Box Example
#
# If there's a section of the notebook you want to emphasize, ensuring learners set a variable correctly before executing it to avoid discrepancies from the expected or explained outcomes in the video, consider using the info box format provided below to spotlight these notes. For critical or immediate notices, the background color #f7d7e1 (light pink) can be used for additional visibilty.

# %% [markdown]
# <p style="background-color:#fff1d7; padding:15px; "> <b>(Note: <code>max_articles_num = 500</code>):</b> To achieve a more comprehensive context for the Language Learning Model, a larger number of articles is generally more beneficial. In this lab, we've initially set <code>max_articles_num</code> to 500 for speedier results, allowing you to observe the outcomes faster. Once you've done an initial run, consider increasing this value to 750 or 1,000. You'll likely notice that the context provided to the LLM becomes richer and better. You can experiment by gradually raising this variable for different queries to observe the improvements in the LLM's contextual understanding.</p>

# %%
max_articles_num = 500
df = pd.read_csv('wiki.csv', nrows=max_articles_num)
df.head()

# %% [markdown]
# ## Saving and Loading the Results for Quicker Execution
# If a segment of the code, such as model training, requires extended time to generate outcomes for subsequent cells, consider saving the output and loading the trained model to expedite the process. Additionally, provide learners with the choice to train the model on their own. Refer to the example below for guidance. See the following example.

# %% [markdown]
# <p style="background-color:#fff1d7; padding:15px; "> <b>(Note: <code>load_pretrained_model = True</code>):</b> We've saved the trained model and are loading it here for speedier results, allowing you to observe the outcomes faster. Once you've done an initial run, you may set <code>load_pretrained_model</code> to <code>False</code> to train the model yourself. This can take some time to finsih, depending the value you set for the <code>epochs</code>.</p>

# %%
import pickle
load_pretrained_model = True
if load_pretrained_model:
    trained_model_file = open('./data/pretrained_model', 'rb')    
    db = pickle.load(trained_model_file)
    trained_model_file.close()
else:
    model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=16, warmup_steps=100)
    # Saving the results for the first time.
    # trained_model_file = open('pretrained_model', 'ab')
    # pickle.dump(model, trained_model_file)                    
    # trained_model_file.close()

# %% [markdown]
# ## JSON Viewer Example

# %%
from IPython.display import JSON
import json

js = [
  {
    "type": "Title",
    "element_id": "bff1fd0ec25e78f1224ad7309a1e79c4",
    "text": "B All Experimental Results",
    "metadata": {
      "filetype": "application/pdf",
      "languages": [
        "eng"
      ],
      "page_number": 1,
      "filename": "CoT.pdf"
    }
  },
  {
    "type": "NarrativeText",
    "element_id": "ebf8dfb149bcbbd8c4b7f9a7046900a9",
    "text": "This section contains tables for experimental results for varying models and model sizes, on all benchmarks, for standard prompting vs. chain-of-thought prompting.",
    "metadata": {
      "filetype": "application/pdf",
      "languages": [
        "eng"
      ],
      "page_number": 1,
      "parent_id": "bff1fd0ec25e78f1224ad7309a1e79c4",
      "filename": "CoT.pdf"
    }
  },
]

JSON(json.dumps(js))

# %% [markdown]
# ## Short Course Labs: Guidelines and Notes
# This cell contains the main guidelines for preparing short course labs.
#
# For the title of the lesson/lab, sections and subsections please use the following headings.
#
# # Lab/Lesson Title
# ## Sections
# ### Subsections
#
# Here are some additional notes and guidelines for having a more engaging and learner-friendly notebook labs:
#
# - **utils.py:** The lab may implement an appropriate level of abstraction, for example, with a utils.py file to keep the learner-facing code clean and focused on essential concepts and implementation details.
#
# - **Consistency and clarity:** Lab exercises maintain a consistent format for markdown and code cells. Written content is clear and concise.
#
# - **Code readability:** Code readability and interpretability should be prioritized over excessive optimization of functions.
#
# - **Engagement:** Please encourage learners to modify some lines of the code and try the code themselves.
